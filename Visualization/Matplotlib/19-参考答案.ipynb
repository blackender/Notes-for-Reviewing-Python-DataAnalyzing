# %% [markdown]
# ## 作业要求
#
# 1. 将下面的数据绘制成饼图。
# 2. 设置阴影效果
# 3. 将Chrome对应分块从饼图中分离出来，距离设为0.05。
# 4. 设置显示分块占比信息，保留两位小数。
# 5. 占比信息以白色文字显示，分块名以黑色文字显示。
# 6. 将Edge和Safari的占比的字体大小设置为10，其余为12.

# %%
# 导入包
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %%
# 创建字体管理对象，指向具体的字体文件
font = font_manager.FontProperties(
    fname="/System/Library/Fonts/STHeiti Light.ttc", size=14, weight=4
)

# %%
# 实验数据
data = {
    "Chrome": 0.6098,
    "Internet Explorer": 0.1218,
    "FireFox": 0.1147,
    "Edge": 0.0415,
    "Safari": 0.0372,
    "其他浏览器": 0.075
}

# %%
patches, texts, autotexts = plt.pie(
    data.values(),
    labels=data.keys(),
    explode=(0.05,0,0,0,0,0),
    autopct="%.2f%%",
    textprops={"fontproperties":font},
    shadow=True
)
plt.title("浏览器市场份额", fontproperties=font)
for autotext in autotexts:
    autotext.set_color("w")
    autotext.set_size(12)
autotexts[3].set_size(10)
autotexts[4].set_size(10)
for text in texts:
    text.set_color("k")
plt.show()
