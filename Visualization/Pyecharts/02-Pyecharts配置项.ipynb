# %%
# 在jupyterlab中使用pyecharts的环境设置
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
# 导入包

# Faker是pyecharts提供的一个测试数据生成模块
from pyecharts.faker import Faker
# Bar是条形图和Scatter是散点图
from pyecharts.charts import Bar, Scatter
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode

# %%
help(Faker)
# Out:
# Help on _Faker in module pyecharts.faker object:
#
# class _Faker(builtins.object)
#  |  Methods defined here:
#  |
#  |  choose(self) -> list
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  img_path(path: str, prefix: str = 'images') -> str
#  |
#  |  rand_color() -> str
#  |
#  |  values(start: int = 20, end: int = 150) -> list
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  animal = ['河马', '蟒蛇', '老虎', '大象', '兔子', '熊猫', '狮子']
#  |
#  |  cars = ['宝马', '法拉利', '奔驰', '奥迪', '大众', '丰田', '特斯拉']
#  |
#  |  clock = ['12a', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a', '9a', ...
#  |
#  |  clothes = ['衬衫', '毛衣', '领带', '裤子', '风衣', '高跟鞋', '袜子']
#  |
#  |  country = ['China', 'Canada', 'Brazil', 'Russia', 'United States', 'Af...
#  |
#  |  days_attrs = ['0天', '1天', '2天', '3天', '4天', '5天', '6天', '7天', '8天', '9...
#  |
#  |  days_values = [22, 1, 6, 4, 4, 2, 4, 10, 16, 15, 23, 10, 25, 1, 8, 19,...
#  |
#  |  dogs = ['哈士奇', '萨摩耶', '泰迪', '金毛', '牧羊犬', '吉娃娃', '柯基']
#  |
#  |  drinks = ['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛']
#  |
#  |  fruits = ['草莓', '芒果', '葡萄', '雪梨', '西瓜', '柠檬', '车厘子']
#  |
#  |  guangdong_city = ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市', '广州市', '惠州市']
#  |
#  |  months = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月',...
#  |
#  |  phones = ['小米', '三星', '华为', '苹果', '魅族', 'VIVO', 'OPPO']
#  |
#  |  provinces = ['广东省', '北京市', '上海市', '江西省', '湖南省', '浙江省', '江苏省']
#  |
#  |  visual_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8',...
#  |
#  |  week = ['周一', '周二', '周三', '周四', '周五', '周六', '周日']
#  |
#  |  week_en = ['Saturday', 'Friday', 'Thursday', 'Wednesday', 'Tuesday', '...

# %% [markdown]
# ## 设置初始化配置项
#
# 通过绘图对象构造函数的`init_opts`参数接收的的`InitOpts`对象
#
# ### InitOpts - 初始化配置项
#
# 配置图像的宽度、高度、主题风格、背景色等信息

# %%
bar = (
    # 初始化设置图片宽400px，高300px
    Bar(init_opts=opts.InitOpts(
        width="400px",
        height="300px"
    ))
    .add_xaxis(Faker.choose()) # 使用Faker随机生成x轴数据
    .add_yaxis("产品", Faker.values()) #使用Faker随机生成y轴数据
)
# 绘图
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7f8e72171297448fbd44215bdf8b0c44" class="chart-container" style="width:400px; height:300px; "></div>
#     <script>
#         var chart_7f8e72171297448fbd44215bdf8b0c44 = echarts.init(
#             document.getElementById('7f8e72171297448fbd44215bdf8b0c44'), 'white', {renderer: 'canvas'});
#         var option_7f8e72171297448fbd44215bdf8b0c44 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4ea7\u54c1",
#             "legendHoverLink": true,
#             "data": [
#                 26,
#                 25,
#                 79,
#                 101,
#                 148,
#                 48,
#                 29
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4ea7\u54c1"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_7f8e72171297448fbd44215bdf8b0c44.setOption(option_7f8e72171297448fbd44215bdf8b0c44);
#     </script>
# </body>
# </html>

# %% [markdown]
# #### AnimationOpts - 动画配置项
#
# 配置图像是否开启动画（默认是True），做大量数据分析的时候可以考虑在初始化项中将其设为False

# %%
bar = (
    # 初始化设置图片宽400px，高300px
    Bar(init_opts=opts.InitOpts(
        width="400px",
        height="300px",
        animation_opts = opts.AnimationOpts(animation=False)
    ))
    .add_xaxis(Faker.choose()) # 使用Faker随机生成x轴数据
    .add_yaxis("产品", Faker.values()) #使用Faker随机生成y轴数据
)
# 绘图
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="3eb4a03de3ba49da85b1583cc10cbc6d" class="chart-container" style="width:400px; height:300px; "></div>
#     <script>
#         var chart_3eb4a03de3ba49da85b1583cc10cbc6d = echarts.init(
#             document.getElementById('3eb4a03de3ba49da85b1583cc10cbc6d'), 'white', {renderer: 'canvas'});
#         var option_3eb4a03de3ba49da85b1583cc10cbc6d = {
#     "animation": false,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4ea7\u54c1",
#             "legendHoverLink": true,
#             "data": [
#                 36,
#                 54,
#                 86,
#                 106,
#                 51,
#                 21,
#                 132
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4ea7\u54c1"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_3eb4a03de3ba49da85b1583cc10cbc6d.setOption(option_3eb4a03de3ba49da85b1583cc10cbc6d);
#     </script>
# </body>
# </html>

# %% [markdown]
# ## 设置初始化配置项
#
# 通过绘图对象的`set_global_opts`函数接收配置项对象
#
# ### TitleOpts - 标题配置项
#
# 配置图像的标题和子标题**在set_global_opts中配置**

# %%
bar = (
    # 初始化设置图片宽400px，高300px
    Bar(init_opts=opts.InitOpts(
        width="400px",
        height="300px"
    ))
    .add_xaxis(Faker.choose()) # 使用Faker随机生成x轴数据
    .add_yaxis("产品", Faker.values()) #使用Faker随机生成y轴数据
    .set_global_opts(
        title_opts=opts.TitleOpts( # 设置标题相关信息
            title="产品销量", # 设置标题名
            subtitle="（个）", # 设置子标题
            # 设置标题位置距离右边25px，也可以设置其他位置，例如 pos_top
            pos_right="25px",
            title_textstyle_opts=opts.TextStyleOpts(font_size=12) # 设置标题字体风格
        )
    )
)
# 绘图
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9fbebd9f12ec4a0cb29efe0118acac04" class="chart-container" style="width:400px; height:300px; "></div>
#     <script>
#         var chart_9fbebd9f12ec4a0cb29efe0118acac04 = echarts.init(
#             document.getElementById('9fbebd9f12ec4a0cb29efe0118acac04'), 'white', {renderer: 'canvas'});
#         var option_9fbebd9f12ec4a0cb29efe0118acac04 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4ea7\u54c1",
#             "legendHoverLink": true,
#             "data": [
#                 112,
#                 68,
#                 20,
#                 100,
#                 20,
#                 149,
#                 20
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4ea7\u54c1"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4ea7\u54c1\u9500\u91cf",
#             "target": "blank",
#             "subtext": "\uff08\u4e2a\uff09",
#             "subtarget": "blank",
#             "right": "25px",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_9fbebd9f12ec4a0cb29efe0118acac04.setOption(option_9fbebd9f12ec4a0cb29efe0118acac04);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### LegendOpts - 图例配置项
#
# 配置图像的图例**在set_global_opts中配置**

# %%
bar = (
    # 初始化设置Bar图片宽600px，高300px
    Bar(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.choose())
    #使用Faker随机生成y轴数据
        # gap=0，设置条行间的间隔为0
    .add_yaxis("商家1", Faker.values(), gap=0)
    #添加一组新的y轴取值，使用Faker随机生成y轴数据
        # gap=0，设置条行间的间隔为0
    .add_yaxis("商家2", Faker.values(), gap=0)
    .set_global_opts(
        title_opts=opts.TitleOpts( # 设置标题相关信息
            title="产品销量", # 设置标题名
            subtitle="（个）", # 设置子标题
            pos_right="25px", # 设置标题位置距离右边25px
            title_textstyle_opts=opts.TextStyleOpts(font_size=12) # 设置标题字体风格
        ),
        legend_opts=opts.LegendOpts(
            selected_mode="single", # 设置每次只能选择显式一种图例对应的数据（默认是multiple）
            orient="vertical" # 设置图例垂直排列显示（默认是horizontal）
        )
    )
)
# 绘图
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="24c7240e94674d18a451894b11a43581" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_24c7240e94674d18a451894b11a43581 = echarts.init(
#             document.getElementById('24c7240e94674d18a451894b11a43581'), 'white', {renderer: 'canvas'});
#         var option_24c7240e94674d18a451894b11a43581 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb61",
#             "legendHoverLink": true,
#             "data": [
#                 91,
#                 73,
#                 93,
#                 108,
#                 82,
#                 79,
#                 64
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": 0,
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb62",
#             "legendHoverLink": true,
#             "data": [
#                 131,
#                 73,
#                 142,
#                 74,
#                 87,
#                 69,
#                 25
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": 0,
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb61",
#                 "\u5546\u5bb62"
#             ],
#             "selected": {},
#             "selectedMode": "single",
#             "show": true,
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4ea7\u54c1\u9500\u91cf",
#             "target": "blank",
#             "subtext": "\uff08\u4e2a\uff09",
#             "subtarget": "blank",
#             "right": "25px",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_24c7240e94674d18a451894b11a43581.setOption(option_24c7240e94674d18a451894b11a43581);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### VisualMapOpts - 视觉映射配置项
#
# 配置图像的视觉映射效果**在set_global_opts中配置**

# %%
yValues = [(a, b) for a,b in zip(Faker.values(), Faker.values())]
print(yValues)
scatter = (
    # 初始化设置Scatter图片宽600px，高300px
    Scatter(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.clothes)
    #使用Faker随机生成y轴数据
    .add_yaxis("商家", yValues)
)
# 绘图，默认没有设置视觉映射时只展示y轴上第一个维度的值
scatter.render_notebook()
# Out:
# [(71, 32), (89, 109), (62, 110), (150, 70), (73, 124), (47, 135), (147, 106)]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="2481a6fdbd5e4a519996fe195ec3cd4f" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_2481a6fdbd5e4a519996fe195ec3cd4f = echarts.init(
#             document.getElementById('2481a6fdbd5e4a519996fe195ec3cd4f'), 'white', {renderer: 'canvas'});
#         var option_2481a6fdbd5e4a519996fe195ec3cd4f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     71,
#                     32
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     89,
#                     109
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     62,
#                     110
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     150,
#                     70
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     73,
#                     124
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     47,
#                     135
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     147,
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_2481a6fdbd5e4a519996fe195ec3cd4f.setOption(option_2481a6fdbd5e4a519996fe195ec3cd4f);
#     </script>
# </body>
# </html>

# %%
scatter = (
    # 初始化设置Scatter图片宽600px，高300px
    Scatter(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.clothes)
    #使用Faker随机生成y轴数据
    .add_yaxis("商家", yValues)
    # 在全局配置项中设置视觉映射
    .set_global_opts(
        # 设置根据y轴上第二个维度的值显示点的大小
        visualmap_opts=opts.VisualMapOpts(type_="size")
    )
)
scatter.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="39309917bf49442dbdcc1e2c5c6eb619" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_39309917bf49442dbdcc1e2c5c6eb619 = echarts.init(
#             document.getElementById('39309917bf49442dbdcc1e2c5c6eb619'), 'white', {renderer: 'canvas'});
#         var option_39309917bf49442dbdcc1e2c5c6eb619 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     71,
#                     32
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     89,
#                     109
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     62,
#                     110
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     150,
#                     70
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     73,
#                     124
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     47,
#                     135
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     147,
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#         chart_39309917bf49442dbdcc1e2c5c6eb619.setOption(option_39309917bf49442dbdcc1e2c5c6eb619);
#     </script>
# </body>
# </html>

# %%
scatter = (
    # 初始化设置Scatter图片宽600px，高300px
    Scatter(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.clothes)
    #使用Faker随机生成y轴数据
    .add_yaxis("商家", yValues)
    # 在全局配置项中设置视觉映射
    .set_global_opts(
        # 设置根据y轴上第二个维度的值显示点的颜色
        # rang_text用于设置range条两端的文本
        visualmap_opts=opts.VisualMapOpts(type_="color", range_text=["高", "低"])
    )
)
scatter.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5dbe4b504c844be0a5d209c9f765678d" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_5dbe4b504c844be0a5d209c9f765678d = echarts.init(
#             document.getElementById('5dbe4b504c844be0a5d209c9f765678d'), 'white', {renderer: 'canvas'});
#         var option_5dbe4b504c844be0a5d209c9f765678d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     71,
#                     32
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     89,
#                     109
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     62,
#                     110
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     150,
#                     70
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     73,
#                     124
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     47,
#                     135
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     147,
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "\u9ad8",
#             "\u4f4e"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#         chart_5dbe4b504c844be0a5d209c9f765678d.setOption(option_5dbe4b504c844be0a5d209c9f765678d);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### TooltipOpts - 提示框配置项
#
# 配置图像的提示框效果**在set_global_opts中配置**

# %%
scatter = (
    # 初始化设置Scatter图片宽600px，高300px
    Scatter(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.clothes)
    #使用Faker随机生成y轴数据
    .add_yaxis("商家", Faker.values())
    # 在全局配置项中设置视觉映射
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="提示框配置项实验",
            title_textstyle_opts=opts.TextStyleOpts(font_size=12)
        ),
        tooltip_opts=opts.TooltipOpts(
            # {a}：系列名
            # {b}：数据名（即x轴对应值）
            # {c}：数据值（即x轴值加上y轴值）
            formatter = '系列名：{a} | 数据名：{b} | 数据值：{c}'
        )
    )
)
scatter.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c85e67b3cef34b5d835f7d8a80b2e091" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_c85e67b3cef34b5d835f7d8a80b2e091 = echarts.init(
#             document.getElementById('c85e67b3cef34b5d835f7d8a80b2e091'), 'white', {renderer: 'canvas'});
#         var option_c85e67b3cef34b5d835f7d8a80b2e091 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     31
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     59
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     75
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     83
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     97
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     149
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     95
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": "\u7cfb\u5217\u540d\uff1a{a} | \u6570\u636e\u540d\uff1a{b} | \u6570\u636e\u503c\uff1a{c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u63d0\u793a\u6846\u914d\u7f6e\u9879\u5b9e\u9a8c",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_c85e67b3cef34b5d835f7d8a80b2e091.setOption(option_c85e67b3cef34b5d835f7d8a80b2e091);
#     </script>
# </body>
# </html>

# %%
scatter = (
    # 初始化设置Scatter图片宽600px，高300px
    Scatter(init_opts=opts.InitOpts(
        width="600px",
        height="300px"
    ))
    # 使用Faker随机生成x轴数据
    .add_xaxis(Faker.clothes)
    #使用Faker随机生成y轴数据
    .add_yaxis("商家", Faker.values())
    # 在全局配置项中设置视觉映射
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="提示框配置项实验",
            title_textstyle_opts=opts.TextStyleOpts(font_size=12)
        ),
        tooltip_opts=opts.TooltipOpts(
            # JsCode可以嵌入自定义JS函数
            formatter=JsCode(
                """
                function(params){
                    return params.name + params.value[1]
                }
                """
            )
        )
    )
)
scatter.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="bc0801d02eb44553a30ea7eea96f0129" class="chart-container" style="width:600px; height:300px; "></div>
#     <script>
#         var chart_bc0801d02eb44553a30ea7eea96f0129 = echarts.init(
#             document.getElementById('bc0801d02eb44553a30ea7eea96f0129'), 'white', {renderer: 'canvas'});
#         var option_bc0801d02eb44553a30ea7eea96f0129 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     32
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     131
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     111
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     46
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     34
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     138
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     75
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter":                 function(params){                    return params.name + params.value[1]                }                ,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u63d0\u793a\u6846\u914d\u7f6e\u9879\u5b9e\u9a8c",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_bc0801d02eb44553a30ea7eea96f0129.setOption(option_bc0801d02eb44553a30ea7eea96f0129);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### AxisOpts - 轴配置项
#
# 配置图像的轴显示效果**在set_global_opts中配置**

# %%
bar = (
    # 初始化设置Bar图片宽600px，高300px
    Bar(init_opts=opts.InitOpts(
        width="800px",
        height="400px"
    ))
    # 手动设置一个长名字x轴标签
    .add_xaxis(
        [
            "名字很长的X轴标签名1",
            "名字很长的X轴标签名2",
            "名字很长的X轴标签名3",
            "名字很长的X轴标签名4",
            "名字很长的X轴标签名5",
        ]
    )
    #使用Faker随机生成y轴数据
        # gap=0，设置条行间的间隔为0
    .add_yaxis("商家1", [12, 20, 30, 40, 50])
    #添加一组新的y轴取值，使用Faker随机生成y轴数据
        # gap=0，设置条行间的间隔为0
    .add_yaxis("商家2", [20, 30, 10, 50, 40])
    .set_global_opts(
        # 以x轴为例示范AxisOpt的用法
        xaxis_opts=opts.AxisOpts(
            # 设置x轴label配置：转-15度
            axislabel_opts=opts.LabelOpts(rotate=-15),
            # 设置x轴线条配置
            axisline_opts=opts.AxisLineOpts(symbol="arrow", linestyle_opts=opts.LineStyleOpts(width=2)),
            # 设置x轴刻度线
            axistick_opts=opts.AxisTickOpts(is_inside=True, length=20),
            # 设置x轴的鼠标辅助线效果
            axispointer_opts=opts.AxisPointerOpts(is_show=True)
        )
    )
)
# 绘图
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b4af73650fdd4f4089ad758837da5d1e" class="chart-container" style="width:800px; height:400px; "></div>
#     <script>
#         var chart_b4af73650fdd4f4089ad758837da5d1e = echarts.init(
#             document.getElementById('b4af73650fdd4f4089ad758837da5d1e'), 'white', {renderer: 'canvas'});
#         var option_b4af73650fdd4f4089ad758837da5d1e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb61",
#             "legendHoverLink": true,
#             "data": [
#                 12,
#                 20,
#                 30,
#                 40,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb62",
#             "legendHoverLink": true,
#             "data": [
#                 20,
#                 30,
#                 10,
#                 50,
#                 40
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb61",
#                 "\u5546\u5bb62"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "symbol": "arrow",
#                 "lineStyle": {
#                     "show": true,
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": true,
#                 "length": 20
#             },
#             "axisLabel": {
#                 "show": true,
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "axisPointer": {
#                 "show": true,
#                 "type": "line",
#                 "triggerTooltip": true,
#                 "triggerOn": "mousemove|click"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e\u540d1",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e\u540d2",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e\u540d3",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e\u540d4",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e\u540d5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_b4af73650fdd4f4089ad758837da5d1e.setOption(option_b4af73650fdd4f4089ad758837da5d1e);
#     </script>
# </body>
# </html>
